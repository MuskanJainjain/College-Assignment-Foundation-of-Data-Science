# %% [markdown]
# <a href="https://colab.research.google.com/github/MuskanJainjain/College-Assignment-Foundation-of-Data-Science/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question 1**

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.7.1

# %% [markdown]
# **Question 2**

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints  = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# **Question 3**

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,9])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# **Question 4**

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints,ypoints,'o')
plt.show()

# %% [markdown]
# **Question 5**

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,4,7,8])
ypoints = np.array([6,5,2,9])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# **Question 6**

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])

plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# **Question 7**

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10,5,7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# **Question 8**

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# **Question 9**

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10,5,7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# **Question 10**

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,10])

plt.plot(ypoints,marker = '*')
plt.show()
